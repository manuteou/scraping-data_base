# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
urls= ['https://www.snrbaudouin.com/avant-l-art-moderne-c102x3977606',
       'https://www.snrbaudouin.com/art-moderne-art-contemporain-c102x3977610',
       'https://www.snrbaudouin.com/artistes-modernes-et-contemporains-c102x3977605',
       'https://www.snrbaudouin.com/architecture-c102x3977621',
       'https://www.snrbaudouin.com/arts-decoratifs-arts-appliques-c102x3977604',
       'https://www.snrbaudouin.com/photographie-c102x3977602',
       'https://www.snrbaudouin.com/galerie-pierre-matisse-c102x3977712',
       'https://www.snrbaudouin.com/reperes-galerie-lelong-c102x3977675',
       'https://www.snrbaudouin.com/arts-du-spectacle-et-musique-c102x3977609',
       'https://www.snrbaudouin.com/mode-textiles-c102x3977607',
       'https://www.snrbaudouin.com/cheval-d-attaque-c102x3977648',
       'https://www.snrbaudouin.com/le-dernier-terrain-vague-c102x3977665',
       'https://www.snrbaudouin.com/paris-france-c102x3977612',
       'https://www.snrbaudouin.com/esoterisme-c102x3977611',
       'https://www.snrbaudouin.com/jeunesse-et-bandes-dessinees-c102x3977616']

# %%
df_ebay = pd.read_csv('FileExchange.csv', sep=';', encoding='latin')

# %%
df = df_ebay["Titre de l'objet"].str.split(" - ", expand=True, n=1)
df.columns = ['titre','nom']
df['titre'] = df['titre'].apply(lambda x: x.replace("."," ").replace(","," ").replace("!"," ").replace(")"," ").replace("("," ").replace("[\]"," ").replace('"',' ').replace("/"," "))
df['titre'] = df['titre'].str.replace(r" +"," ")
df['titre'] = df['titre'].str.lower()
# Out:
# <ipython-input-4-1294c86298e4>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['titre'] = df['titre'].str.replace(r" +"," ")

# %%
results = []
for url in urls:
    print("collecting url:",url)
    tempo = []
    reponse = requests.get(url)
    soup = BeautifulSoup(reponse.text, 'html.parser')
    titre = soup.findAll("h3")
    for t in titre:
        tempo.append(t.get_text())
    for i in range(len(tempo)):
        tempo[i] = tempo[i].replace("""<h3 class="PBMainTxt">""","")
        tempo[i] = tempo[i].replace("""</h3>""","")
        tempo[i] = tempo[i].lower()
        tempo[i] = tempo[i].split("-")[0]
        tempo[i] = tempo[i].replace("."," ").replace(","," ").replace("!"," ").replace(")"," ").replace("("," ").replace("[\]"," ").replace('"',' ').replace("/"," ")
        tempo[i] = re.sub(" +"," ",tempo[i])
        tempo[i] = tempo[i].strip()
        try :
            tempo[i] = tempo[i].split(']')[1]
        except(IndexError):
            print('jump')
    results.append(tempo)
# Out:
# collecting url: https://www.snrbaudouin.com/avant-l-art-moderne-c102x3977606
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/art-moderne-art-contemporain-c102x3977610
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/artistes-modernes-et-contemporains-c102x3977605
# jump
# collecting url: https://www.snrbaudouin.com/architecture-c102x3977621
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/arts-decoratifs-arts-appliques-c102x3977604
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/photographie-c102x3977602
# collecting url: https://www.snrbaudouin.com/galerie-pierre-matisse-c102x3977712
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/reperes-galerie-lelong-c102x3977675
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/arts-du-spectacle-et-musique-c102x3977609
# collecting url: https://www.snrbaudouin.com/mode-textiles-c102x3977607
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/cheval-d-attaque-c102x3977648
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/le-dernier-terrain-vague-c102x3977665
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/paris-france-c102x3977612
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/esoterisme-c102x3977611
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# jump
# collecting url: https://www.snrbaudouin.com/jeunesse-et-bandes-dessinees-c102x3977616

# %%
somme = 0
livres = []
for n in range(len(results)):
    lst = [t for t in titre if t in results[n]]
    somme += len(lst)
    livres += lst
print('nombre de livre à update:',somme)
livres
# Out:
# nombre de livre à update: 102
# ["l'art moderne année 1882 : 53 livraisons",
#  'aphorismes',
#  'le trésor de naples les joyaux de san gennaro',
#  'les arts en seine le paradis des impressionnistes',
#  "dessins du siècle d'or hollandais la collection jean de grez",
#  "dieux et héros catalogue d'exposition",
#  'le xviième siècle racines et développements',
#  'jordanie sur les pas des archéologues',
#  'intrigantes incertitudes',
#  'on ne regarde pas la lune mais le doigt qui montre la lune',
#  'artistes en chine',
#  "misia l'inspiratrice",
#  "hommage a ernst et hildy beyeler l'autre collection",
#  'bmw art cars',
#  "l'art medecine actes du colloque",
#  'atelier 86 choix de rudi fuchs',
#  'le moine et le demon art contemporain chinois',
#  "objets d'artistes",
#  'pierre nahon marianne marchands un portrait',
#  'voyages croises reporting system',
#  "indomania l'art populaire indien",
#  'histoires de voir show and tell',
#  'intrigantes incertitudes',
#  "l'art du japon au vingtieme siecle pensée formes résistances",
#  'voyages croises reporting system',
#  "le regard bleu d'arthur rimbaud",
#  "le triomphe de l'art américain tome 1 : l'expressionnisme abstrait",
#  "architectures de la culture culture de l'architecture",
#  'architectures publiques 1990',
#  "les dessins d'architecture du xviiième siècle",
#  'gabo space and kinetic constructions',
#  'sculpture of the tellem and the dogon',
#  'canogar millares rivera saura four spanish painters',
#  'balthus paintings and drawings 1934 to 1977',
#  'marc chagall water colors',
#  'marc chagall paintings',
#  'jean dubuffet retrospective exhibition',
#  'alberto giacometti',
#  'the early paintings of joan miró',
#  'riopelle sculpture',
#  'marc chagall',
#  'marc chagall recent paintings 1966',
#  'loren maciver recent paintings',
#  'joan miro exhibition of early paintings from 1918 to 1925',
#  'miró peintures sauvages 1934 to 1953',
#  'miró sobreteixims',
#  'rouan targoum paintings and drawings 1973 to 1981',
#  'marc chagall the four seasons gouaches',
#  'jan dibbets peintures repères n°57',
#  'jim dine monotypes et gravures repères n°4',
#  'magnelli les années 20 repères n°26',
#  'miró sculptures repères n°22',
#  'riopelle repères n° 9',
#  'george segal repères n°23',
#  'garcía sevilla peintures repères n°45',
#  'steinberg repères n°30',
#  'wifredo lam repères n°33',
#  'monory toxique repères n°11',
#  'garache peintures récentes repères n°12',
#  "précis d'extravagance",
#  'la mode parisienne 1912',
#  'parachute art contemporain numéro 34 mars avril mai 1984',
#  'gorgomar',
#  'dieu est mort dieu le roi des fameux',
#  "cheval d'attaque numéro 19 1978",
#  'mézavi traduit du babil',
#  'parachute art contemporain numéro 20 automne 1980',
#  'parachute art contemporain numéro 21 hiver 1980',
#  'parachute art contemporain numéro 23 été 1981',
#  'parachute art contemporain numéro 24 automne 1981',
#  'parachute art contemporain numéro 38 mars avril mai 1985',
#  'sagesse et amour méditations quotidiennes',
#  "les grands symboles de l'humanite",
#  'le prophete',
#  "l'aide de dieu dieu les saints les anges",
#  'ces liens qui nous unissent la science et la nouvelle sagesse',
#  'vivre la mort voyages à travers les traditions',
#  "la science devant la survie de l'ame expériences aux portes de la mort",
#  'a la lumiere de la conscience',
#  'la vie du christ après sa mort',
#  'du developpement personnel au transpersonnel',
#  "l'ecrit de l'ame",
#  'le karma devoilé',
#  "l'homme semence ou la nouvelle spiritualité",
#  "les explorateurs de l'invisible",
#  'les maitres de la conscience planetaire',
#  'pour une humanite nouvelle',
#  'aux sources du rite ecossais ancien',
#  'ces ondes qui nous soignent la géobiologie',
#  'la mort est un nouveau soleil',
#  'la théorie de la relativité restreinte',
#  "l'ame des pierres precieuses dans la science des sept rayons",
#  'le flambeau de la vision',
#  'les maîtres du mythe à la réalité',
#  'les mysteres de notre vie',
#  'les portes du rêve',
#  "l'evangile eternel et mondial bimillénaire de l'apocalypse an 96",
#  'mettre la vie au centre de nos vies pour une culture biocentrique',
#  'orages',
#  "pratique de l'experience spirituelle",
#  'se liberer de la souffrance et construire son bonheur',
#  'sous le signe de la grande experience']
